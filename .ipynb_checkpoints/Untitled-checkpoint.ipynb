# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.info() #get the total number of entries in each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#we find that there is no null data..so we wont be needing to replace missing data

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
# we find that there are same amount of mobiles for each price range

# %%
df['touch_screen'].value_counts()
# Out:
# 1    1006
# 0     994
# Name: touch_screen, dtype: int64

# %%
#we find there are mobiles even without touchscreens here

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df = df[['battery_power', 'blue', 'dual_sim', 'fc', 'four_g',    #including only important aspects 
       'int_memory', 'mobile_wt', 'n_cores', 'pc',
        'ram','talk_time', 'three_g',
       'touch_screen', 'wifi', 'price_range']] #general audiance wont be looking much for clock speed,px height,px width,screen height and width and depth of mobile

# %%
df
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  mobile_wt  \
# 0               842     0         0   1       0           7        188
# 1              1021     1         1   0       1          53        136
# 2               563     1         1   2       1          41        145
# 3               615     1         0   0       0          10        131
# 4              1821     1         0  13       1          44        141
# ...             ...   ...       ...  ..     ...         ...        ...
# 1995            794     1         1   0       1           2        106
# 1996           1965     1         1   0       0          39        187
# 1997           1911     0         1   1       1          36        108
# 1998           1512     0         0   4       1          46        145
# 1999            510     1         1   5       1          45        168
#
#       n_cores  pc   ram  talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
#since we cant be bothering customer with too much data to fill out..we r going tom reduce features furthur
df = df[['battery_power', 'blue', 'dual_sim', 'fc', 'four_g',    #including only important aspects 
       'int_memory','pc',
        'ram','three_g',
       'touch_screen', 'wifi', 'price_range']]

# %%
df
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  pc   ram  \
# 0               842     0         0   1       0           7   2  2549
# 1              1021     1         1   0       1          53   6  2631
# 2               563     1         1   2       1          41   6  2603
# 3               615     1         0   0       0          10   9  2769
# 4              1821     1         0  13       1          44  14  1411
# ...             ...   ...       ...  ..     ...         ...  ..   ...
# 1995            794     1         1   0       1           2  14   668
# 1996           1965     1         1   0       0          39   3  2032
# 1997           1911     0         1   1       1          36   3  3057
# 1998           1512     0         0   4       1          46   5   869
# 1999            510     1         1   5       1          45  16  3919
#
#       three_g  touch_screen  wifi  price_range
# 0           0             0     1            1
# ...

# %%
df.describe() #get the stats
# Out:
#        battery_power       blue     dual_sim           fc       four_g  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     0.509500     4.309500     0.521500
# std       439.418206     0.5001     0.500035     4.341444     0.499662
# min       501.000000     0.0000     0.000000     0.000000     0.000000
# 25%       851.750000     0.0000     0.000000     1.000000     0.000000
# 50%      1226.000000     0.0000     1.000000     3.000000     1.000000
# 75%      1615.250000     1.0000     1.000000     7.000000     1.000000
# max      1998.000000     1.0000     1.000000    19.000000     1.000000
#
#         int_memory           pc          ram      three_g  touch_screen  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean     32.046500     9.916500  2124.213000     0.761500      0.503000
# std      18.145715     6.064315  1084.732044     0.426273      0.500116
# ...

# %%
df.corr() #get the correlation between each and every avilable feature in dataset
# Out:
#                battery_power      blue  dual_sim        fc    four_g  \
# battery_power       1.000000  0.011252 -0.041847  0.033334  0.015665
# blue                0.011252  1.000000  0.035198  0.003593  0.013443
# dual_sim           -0.041847  0.035198  1.000000 -0.029123  0.003187
# fc                  0.033334  0.003593 -0.029123  1.000000 -0.016560
# four_g              0.015665  0.013443  0.003187 -0.016560  1.000000
# int_memory         -0.004004  0.041177 -0.015679 -0.029133  0.008690
# pc                  0.031441 -0.009952 -0.017143  0.644595 -0.005598
# ram                -0.000653  0.026351  0.041072  0.015099  0.007313
# three_g             0.011522 -0.030236 -0.014008  0.001793  0.584246
# touch_screen       -0.010516  0.010061 -0.017117 -0.014828  0.016758
# wifi               -0.008343 -0.021863  0.022740  0.020085 -0.017620
# price_range         0.200723  0.020573  0.017444  0.021998  0.014772
#
# ...

# %%
#ram is having the maximum impact on the price range followed by battery

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   dual_sim       2000 non-null   int64
#  3   fc             2000 non-null   int64
#  4   four_g         2000 non-null   int64
#  5   int_memory     2000 non-null   int64
#  6   mobile_wt      2000 non-null   int64
#  7   pc             2000 non-null   int64
#  8   ram            2000 non-null   int64
#  9   three_g        2000 non-null   int64
#  10  touch_screen   2000 non-null   int64
#  11  wifi           2000 non-null   int64
#  12  price_range    2000 non-null   int64
# dtypes: int64(13)
# memory usage: 203.2 KB

# %%
df['blue'].value_counts()
# Out:
# 0    1010
# 1     990
# Name: blue, dtype: int64

# %%
df['fc'].value_counts() #no front cam has the maximum customers
# Out:
# 0     474
# 1     245
# 2     189
# 3     170
# 5     139
# 4     133
# 6     112
# 7     100
# 9      78
# 8      77
# 10     62
# 11     51
# 12     45
# 13     40
# 16     24
# 15     23
# 14     20
# 18     11
# 17      6
# 19      1
# Name: fc, dtype: int64

# %%
df['pc'].value_counts()#10mp back cam has the maximum customers
# Out:
# 10    122
# 7     119
# 9     112
# 20    110
# 1     104
# 14    104
# 0     101
# 2      99
# 17     99
# 6      95
# 4      95
# 3      93
# 15     92
# 12     90
# 8      89
# 16     88
# 13     85
# 19     83
# 18     82
# 11     79
# 5      59
# Name: pc, dtype: int64

# %%
df['int_memory'].value_counts()[8] #8gb internal memory has total has total of 37 customers
# Out:
# 37

# %%
df['int_memory'].value_counts()[32] #32gb internal memory has total has total of 31 customers
# Out:
# 31

# %%
df['int_memory'].value_counts()[64] #64gb internal memory has total has total of 31 customers
# Out:
# 31

# %%
df['int_memory'].max() #64 gb internal memory is the max
# Out:
# 64

# %%
df['ram'].max() #4gb ram is the max
# Out:
# 3998

# %%
df['battery_power'].value_counts()
# Out:
# 1872    6
# 618     6
# 1589    6
# 1715    5
# 1807    5
#        ..
# 660     1
# 1452    1
# 1005    1
# 1372    1
# 858     1
# Name: battery_power, Length: 1094, dtype: int64

# %%
df['battery_power'].max()#2000mah is the max power
# Out:
# 1998

# %%
df['battery_power'].min()#2000mah is the max power
# Out:
# 501

# %%
df['battery_power'] .value_counts(ascending=True)
# Out:
# 858     1
# 1421    1
# 1887    1
# 1587    1
# 1755    1
#        ..
# 1414    5
# 1807    5
# 618     6
# 1589    6
# 1872    6
# Name: battery_power, Length: 1094, dtype: int64

# %%
df[df['battery_power'] < 1000].value_counts()
# Out:
# battery_power  blue  dual_sim  fc  four_g  int_memory  pc  ram   three_g  touch_screen  wifi  price_range
# 501            0     0         12  1       54          19  2346  1        0             1     1              1
# 831            0     1         7   1       26          11  1704  1        1             1     0              1
# 826            0     0         3   0       62          19  1998  0        0             0     1              1
#                      1         0   1       57          0   323   1        0             1     0              1
#                1     1         0   1       58          1   2863  1        0             1     2              1
#                                                                                                             ..
# 659            0     1         7   1       5           10  2190  1        1             0     1              1
# ...

# %%
df.loc[df.battery_power > 700].value_counts()
# Out:
# battery_power  blue  dual_sim  fc  four_g  int_memory  pc  ram   three_g  touch_screen  wifi  price_range
# 701            1     0         7   0       15          11  1756  1        1             1     1              1
# 1571           0     0         1   0       30          3   586   0        1             1     0              1
# 1569           1     1         4   1       54          6   3905  1        0             0     3              1
#                0     1         17  0       44          20  1260  1        0             0     1              1
#                                8   0       59          16  3672  1        0             1     3              1
#                                                                                                             ..
# 1122           0     0         0   1       40          14  1456  1        1             0     1              1
# ...

# %%
(700 <= df['battery_power']) & (df['battery_power'] < 1000)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995     True
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: battery_power, Length: 2000, dtype: bool

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df,hue='blue')

# %%
sns.barplot(x=df.blue,y=df.price_range)
# Out:
# <AxesSubplot:xlabel='blue', ylabel='price_range'>

# %%
sns.barplot(x=df.battery_power,y=df.price_range)
# Out:
# <AxesSubplot:xlabel='battery_power', ylabel='price_range'>

# %%
df
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  pc   ram  \
# 0               842     0         0   1       0           7   2  2549
# 1              1021     1         1   0       1          53   6  2631
# 2               563     1         1   2       1          41   6  2603
# 3               615     1         0   0       0          10   9  2769
# 4              1821     1         0  13       1          44  14  1411
# ...             ...   ...       ...  ..     ...         ...  ..   ...
# 1995            794     1         1   0       1           2  14   668
# 1996           1965     1         1   0       0          39   3  2032
# 1997           1911     0         1   1       1          36   3  3057
# 1998           1512     0         0   4       1          46   5   869
# 1999            510     1         1   5       1          45  16  3919
#
#       three_g  touch_screen  wifi  price_range
# 0           0             0     1            1
# ...

# %%
sns.boxplot(x=df.price_range,y=df.int_memory)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='int_memory'>

# %%
sns.barplot(x=df.price_range,y=df.ram)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
df['ram'].value_counts()
# Out:
# 1464    4
# 3142    4
# 2610    4
# 2227    4
# 1229    4
#        ..
# 2312    1
# 2167    1
# 3508    1
# 297     1
# 3919    1
# Name: ram, Length: 1562, dtype: int64

# %%
ram1 = df.ram[(df.ram >= 0) & (df.ram <= 1001)]
ram2 = df.ram[(df.ram >= 1002) & (df.ram <= 2001)]
ram3 = df.ram[(df.ram >= 2002) & (df.ram <= 3001)]
ram4 = df.ram[(df.ram >= 3002) & (df.ram <= 4002)]

# %% [raw]
# ram1

# %%
len(ram1)
# Out:
# 398

# %%
ram1
# Out:
# 7       700
# 9       513
# 14      373
# 15      568
# 29      478
#        ...
# 1972    824
# 1976    495
# 1990    296
# 1995    668
# 1998    869
# Name: ram, Length: 398, dtype: int64

# %%
ram_range = [len(ram1),len(ram2),len(ram3),len(ram4)]

# %%
label = ['0<1gb','1<2gb','2<3gb','3<4gb']

# %%
#explode = [0, 0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = sns.color_palette('dark')
  
# plotting data on chart
plt.pie(ram_range, labels=label, colors=palette_color,
         autopct='%.0f%%')
  
# displaying chart
plt.show()

# %%
sns.barplot(y=ram_range,x=label)
# Out:
# <AxesSubplot:>

# %%
df['battery_power'].max()
# Out:
# 1998

# %%
bat1 = df.battery_power[(df.battery_power >= 0) & (df.battery_power <= 500)]
bat2 = df.battery_power[(df.battery_power >= 501) & (df.battery_power <= 1001)]
bat3 = df.battery_power[(df.battery_power >= 1002) & (df.battery_power <= 2000)]

# %%
bat_range = [len(bat1),len(bat2),len(bat3)]

# %%
label_battery = ['0<500mah','500<1000','1000<2000']

# %%
#explode = [0, 0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = sns.color_palette('dark')
  
# plotting data on chart
plt.pie(bat_range, labels=label_battery, colors=palette_color,
         autopct='%.0f%%')
  
# displaying chart
plt.show()

# %%
sns.barplot(x=label_battery,y=bat_range)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  pc   ram  \
# 0               842     0         0   1       0           7   2  2549
# 1              1021     1         1   0       1          53   6  2631
# 2               563     1         1   2       1          41   6  2603
# 3               615     1         0   0       0          10   9  2769
# 4              1821     1         0  13       1          44  14  1411
# ...             ...   ...       ...  ..     ...         ...  ..   ...
# 1995            794     1         1   0       1           2  14   668
# 1996           1965     1         1   0       0          39   3  2032
# 1997           1911     0         1   1       1          36   3  3057
# 1998           1512     0         0   4       1          46   5   869
# 1999            510     1         1   5       1          45  16  3919
#
#       three_g  touch_screen  wifi  price_range
# 0           0             0     1            1
# ...

# %%
#modeling now

# %%
x = df.drop("price_range",axis=1)
y = df['price_range'].values

# %%
x
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  pc   ram  \
# 0               842     0         0   1       0           7   2  2549
# 1              1021     1         1   0       1          53   6  2631
# 2               563     1         1   2       1          41   6  2603
# 3               615     1         0   0       0          10   9  2769
# 4              1821     1         0  13       1          44  14  1411
# ...             ...   ...       ...  ..     ...         ...  ..   ...
# 1995            794     1         1   0       1           2  14   668
# 1996           1965     1         1   0       0          39   3  2032
# 1997           1911     0         1   1       1          36   3  3057
# 1998           1512     0         0   4       1          46   5   869
# 1999            510     1         1   5       1          45  16  3919
#
#       three_g  touch_screen  wifi
# 0           0             0     1
# 1           1             1     0
# ...

# %%
y
# Out:
# array([1, 2, 2, ..., 3, 0, 3], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x)

# %%
y_pred
# Out:
# array([1.68010823, 1.87240221, 1.60139471, ..., 2.72788596, 0.49013161,
#        2.82278032])

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
error = np.sqrt(mean_squared_error(y,y_pred))

# %%
error
# Out:
# 0.38413621622042454

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dec_tree = DecisionTreeRegressor(random_state=0)
dec_tree.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
dec_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 0,
#  'splitter': 'best'}

# %%
y_pred = dec_tree.predict(x)

# %%
y_pred
# Out:
# array([1., 2., 2., ..., 3., 0., 3.])

# %%
error = np.sqrt(mean_squared_error(y,y_pred))

# %%
error
# Out:
# 0.0
